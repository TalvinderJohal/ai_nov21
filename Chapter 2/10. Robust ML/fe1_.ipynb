# %% [markdown]
# ## Imports

# %%
# pip install --upgrade scikit-learn

# %%
import time
from IPython.display import clear_output
import numpy    as np
import pandas   as pd
import seaborn  as sb
import matplotlib.pyplot as plt
import sklearn  as skl

from sklearn import pipeline      # Pipeline
from sklearn import preprocessing # OrdinalEncoder, LabelEncoder
from sklearn import impute
from sklearn import compose
from sklearn import model_selection # train_test_split
from sklearn import metrics         # accuracy_score, balanced_accuracy_score, plot_confusion_matrix
from sklearn import set_config

set_config(display='diagram') # Useful for display the pipeline

print("Pandas  ", pd.__version__)
print("Sklearn ", skl.__version__) # Try to use 0.24
# Out:
# Pandas   1.3.4
# Sklearn  1.0.2

# %% [markdown]
# ## Get the dataset
# - **CLOUD = True**: Download dataset from Kaggle. Necesary for cloud enviroments like COLAB. **Specify your [kaggle credentials](https://www.kaggle.com/docs/api)**.
# - **CLOUD = False**: Get the dataset from your local machine. **Specify the data path**.

# %%
DATA_PATH = "/Users/talvinderjohal/Desktop/Talvinder Strive Course/ai_nov21/Chapter 2/10. Robust ML"

# %% [markdown]
# ## Load data

# %%
df      = pd.read_csv(DATA_PATH + "/train.csv", index_col='PassengerId')
df_test = pd.read_csv(DATA_PATH + "/test.csv",  index_col='PassengerId')

print("Train DataFrame:", df.shape)
print("Test DataFrame: ", df_test.shape)
# Out:
# Train DataFrame: (891, 11)
# Test DataFrame:  (418, 10)

# %% [markdown]
# ## Check missings

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# Pclass        0
# Name          0
# Sex           0
# Age          86
# SibSp         0
# Parch         0
# Ticket        0
# Fare          1
# Cabin       327
# Embarked      0
# dtype: int64

# %% [markdown]
# # Exercise 1 (2pts):
# Extract the title (Mr, Mrs, ... ) from the "Name" column.
#
# Tips:
# - split(',')[1] to get the 2nd part, and remove the surnamename
# - split('.')[0] to get the 1str part, and remove the name

# %%
# CODE HERE get_Title_from_Name funtion
# Create this function using lambda (not def)

get_Title_from_Name = lambda name: name.split(',')[1].split('.')[0].strip()
df['Title']      = df['Name'].map(get_Title_from_Name)
df_test['Title'] = df_test['Name'].map(get_Title_from_Name)

# %%
assert df['Title'].values[0] == "Mr"
assert df['Title'].values[1] == "Mrs"
assert df['Title'].values[2] == "Miss"

assert df_test['Title'].values[0] == "Mr"
assert df_test['Title'].values[1] == "Mrs"
assert df_test['Title'].values[414] == "Dona"

# %% [markdown]
# # Exercise 2 (1pts):
# Apply the title_dictionary to get a better information about the title. You have to overwrite the Title variable.

# %%
title_dictionary = {
    "Capt": "Officer",
    "Col": "Officer",
    "Major": "Officer",
    "Jonkheer": "Royalty",
    "Don": "Royalty",
    "Sir" : "Royalty",
    "Dr": "Officer",
    "Rev": "Officer",
    "the Countess":"Royalty",
    "Mme": "Mrs",
    "Mlle": "Miss",
    "Ms": "Mrs",
    "Mr" : "Mr",
    "Mrs" : "Mrs",
    "Miss" : "Miss",
    "Master" : "Master",
    "Lady" : "Royalty"
}

# %%
# Use map to apply the prevous dict

df["Title"] =  df.Title.map(title_dictionary)
df_test["Title"] = df_test.Title.map(title_dictionary)

# %%
assert df['Title'].values[886] == "Officer"
assert df_test['Title'].values[417] == "Master"

# %% [markdown]
# # Exercise OPTINAL (0pts):
# Try to extract some information from the feature **Ticket**. Search on Internet if that colum has some kind of information.

# %%
# Out:
# PassengerId
# 892                 330911
# 893                 363272
# 894                 240276
# 895                 315154
# 896                3101298
#                ...
# 1305             A.5. 3236
# 1306              PC 17758
# 1307    SOTON/O.Q. 3101262
# 1308                359309
# 1309                  2668
# Name: Ticket, Length: 418, dtype: object

# %% [markdown]
# # Exercise OPTIONAL (0pts):
# Try to extract some information from the feature **Cabin**. Search on Internet if that colum has some kind of information.

# %%
# Out:
# PassengerId
# 892      NaN
# 893      NaN
# 894      NaN
# 895      NaN
# 896      NaN
#         ...
# 1305     NaN
# 1306    C105
# 1307     NaN
# 1308     NaN
# 1309     NaN
# Name: Cabin, Length: 418, dtype: object

# %% [markdown]
# # Preprocessing
# For X data, notice that...
# - We drop Survived because is the target variable
# - We drop Name because we have extracted the Title: Mr, Mrs, ...
# - We drop Ticket because it has no information -> see df.Ticket.nunique()
# - We drop Cabin because it has a lot of missings (77% are missings)
#
# Then, we identify **numerical** variables and **categorical** variables,

# %%
x = df.drop(columns=["Survived", 'Name', 'Ticket', 'Cabin']) # X DATA (WILL BE TRAIN+VALID DATA)
y = df["Survived"] # 0 = No, 1 = Yes

x_test = df_test.drop(columns=['Name', 'Ticket', 'Cabin']) # # X_TEST DATA (NEW DATA)

# %%
cat_vars  = ['Sex', 'Embarked', 'Title']         # x.select_dtypes(include=[object]).columns.values.tolist()
num_vars  = ['Pclass', 'SibSp', 'Parch', 'Fare', 'Age'] # x.select_dtypes(exclude=[object]).columns.values.tolist()

print("\nNumerical features:\n", num_vars)
print("\nCategorical features:\n", cat_vars)
# Out:
# Numerical features:
#  ['Pclass', 'SibSp', 'Parch', 'Fare', 'Age']
#
# Categorical features:
#  ['Sex', 'Embarked', 'Title']

# %% [markdown]
# # Exercise 3 (2pts):
# Create a **ColumnTransformer for Tree Models**. You need to create 2 pipelines (one for numerical and other for categories). Remember:
# - Categorical pipeline: Some SimpleImputer -> Some Encoder
# - Numerical pipeline: Some SimpleImputer -> NO Encoder

# %%
"""
num_preprocessing = pipeline.Pipeline(steps=[
  # Some SimpleImputer here
])

cat_preporcessing = pipeline.Pipeline(steps=[
  # Some SimpleImputer here
  # Some Encoder here. Remember to handle_unknown
])

tree_prepro = compose.ColumnTransformer(transformers=[
    ('num', num_preprocessing, num_vars),
    ('cat', cat_preporcessing, cat_vars),
], remainder='drop') # Drop other vars not specified in num_vars or cat_vars

tree_prepro
""";

### BEGIN SOLUTION
num_4_treeModels = pipeline.Pipeline(steps=[('imputer', impute.SimpleImputer(strategy='mean')),])
cat_4_treeModels = pipeline.Pipeline(steps=[('imputer', impute.SimpleImputer(strategy='constant', fill_value='missing')),('ordinal', preprocessing.OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value = -1))])
tree_prepro = compose.ColumnTransformer(transformers=[('num', num_4_treeModels, num_vars),('cat', cat_4_treeModels, cat_vars),], remainder='drop')

tree_prepro
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('imputer', SimpleImputer())]),
#                                  ['Pclass', 'SibSp', 'Parch', 'Fare', 'Age']),
#                                 ('cat',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(fill_value='missing',
#                                                                 strategy='constant')),
#                                                  ('ordinal',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1))]),
#                                  ['Sex', 'Embarked', 'Title'])])

# %%
assert type(tree_prepro)      is compose._column_transformer.ColumnTransformer
assert type(num_4_treeModels) is pipeline.Pipeline
assert type(cat_4_treeModels) is pipeline.Pipeline
assert len(num_4_treeModels) == 1
assert len(cat_4_treeModels) == 2

# %% [markdown]
# # Exercise 4 (1pts):
# 1. Complete the diccionary with some Tree Models.
# 2. Then we put each model in a Pipeline where:
#    - first is the prepocessing with the column Transformer
#    - Then is the Tree model
# 3. Display the fullpipeline of the LGBMClassifier

# %%
from sklearn.tree          import DecisionTreeClassifier
from sklearn.ensemble      import RandomForestClassifier
from sklearn.ensemble      import ExtraTreesClassifier
from sklearn.ensemble      import AdaBoostClassifier
from sklearn.ensemble      import GradientBoostingClassifier
from sklearn.experimental  import enable_hist_gradient_boosting # Necesary for HistGradientBoostingClassifier
from sklearn.ensemble      import HistGradientBoostingClassifier
from xgboost               import XGBClassifier
from lightgbm              import LGBMClassifier
from catboost              import CatBoostClassifier
# Out:
# /Users/talvinderjohal/opt/anaconda3/envs/Tally/lib/python3.9/site-packages/sklearn/experimental/enable_hist_gradient_boosting.py:16: UserWarning: Since version 1.0, it is not needed to import enable_hist_gradient_boosting anymore. HistGradientBoostingClassifier and HistGradientBoostingRegressor are now stable and can be normally imported from sklearn.ensemble.
#   warnings.warn(

# %%
tree_classifiers = {
  "Decision Tree": DecisionTreeClassifier(),
  "Extra Trees":   ExtraTreesClassifier(n_estimators=100),
  "Random Forest": RandomForestClassifier(n_estimators=100),
  "AdaBoost":      AdaBoostClassifier(n_estimators=100),
  "Skl GBM":       GradientBoostingClassifier(n_estimators=100),
  "Skl HistGBM":   HistGradientBoostingClassifier(max_iter=100),
  "XGBoost":       XGBClassifier(n_estimators=100),
  "LightGBM":      LGBMClassifier(n_estimators=100),
  "CatBoost":      CatBoostClassifier(n_estimators=100),
}
tree_classifiers = {name: pipeline.make_pipeline(tree_prepro, model) for name, model in tree_classifiers.items()}
tree_classifiers["LightGBM"]
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer())]),
#                                                   ['Pclass', 'SibSp', 'Parch',
#                                                    'Fare', 'Age']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='missing',
#                                                                                  strategy='constant')),
#                                                                   ('ordinal',
#                                                                    OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                   unknown_value=-1))]),
#                                                   ['Sex', 'Embarked',
#                                                    'Title'])])),
#                 ('lgbmclassifier', LGBMClassifier())])

# %%
for pipe in tree_classifiers.values():
    assert type(pipe) is pipeline.Pipeline

# %% [markdown]
# # Exercise 5 (3pts):
# Define a simple split validation strategy with:
# - 80% for train
# - 20% for validation
# - With stratification
# - random_state=0
#
# And train all the models in a for loop

# %%
"""
x_train, x_val, y_train, y_val = model_selection.train_test_split(
    # CODE HERE
)
"""
results = pd.DataFrame({'Model': [], 'Accuracy': [], 'Bal Acc.': [], 'Time': []})

"""
for model_name, model in tree_classifiers.items():
    start_time = time.time()
    
    # FOR EVERY PIPELINE (PREPRO + MODEL) -> TRAIN WITH TRAIN DATA (x_train)
    
    # GET PREDICTIONS USING x_val
    pred = # CODE HERE

    total_time = time.time() - start_time

    results = results.append({"Model":    model_name,
                              "Accuracy": metrics.accuracy_score(y_val, pred)*100,
                              "Bal Acc.": metrics.balanced_accuracy_score(y_val, pred)*100,
                              "Time":     total_time},
                              ignore_index=True)
                              
                              
"""

### BEGIN SOLUTION
x_train, x_test, y_train, y_test = model_selection.train_test_split(x, y, train_size=0.3, stratify=y, random_state=0)
results = pd.DataFrame({'Model': [], 'Accuracy': [], 'Bal Acc.': [], 'Time': []})
for model_name, model in tree_classifiers.items():

    start_time = time.time()
    model.fit(x_train, y_train)
    total_time = time.time() - start_time
        
    pred = model.predict(x_test)
    
    results = results.append({"Model":    model_name,
                              "Accuracy": metrics.accuracy_score(y_test, pred)*100,
                              "Bal Acc.": metrics.balanced_accuracy_score(y_test, pred)*100,
                              "Time":     total_time},
                              ignore_index=True)




results_ord = results.sort_values(by=['Accuracy'], ascending=False, ignore_index=True)
results_ord.index += 1 
results_ord.style.bar(subset=['Accuracy', 'Bal Acc.'], vmin=0, vmax=100, color='#5fba7d')
# Out:
# /Users/talvinderjohal/opt/anaconda3/envs/Tally/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:13:18] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Learning rate set to 0.048423
# 0:	learn: 0.6795697	total: 63.5ms	remaining: 6.28s
# 1:	learn: 0.6666736	total: 63.9ms	remaining: 3.13s
# 2:	learn: 0.6550832	total: 64ms	remaining: 2.07s
# 3:	learn: 0.6435277	total: 64.3ms	remaining: 1.54s
# 4:	learn: 0.6344353	total: 64.6ms	remaining: 1.23s
# 5:	learn: 0.6229371	total: 64.8ms	remaining: 1.01s
# 6:	learn: 0.6108504	total: 65.1ms	remaining: 865ms
# 7:	learn: 0.6010858	total: 65.4ms	remaining: 752ms
# 8:	learn: 0.5911963	total: 65.6ms	remaining: 664ms
# 9:	learn: 0.5810550	total: 65.9ms	remaining: 593ms
# 10:	learn: 0.5717799	total: 66.2ms	remaining: 535ms
# 11:	learn: 0.5646933	total: 66.7ms	remaining: 489ms
# 12:	learn: 0.5561787	total: 67.3ms	remaining: 450ms
# 13:	learn: 0.5509177	total: 67.5ms	remaining: 415ms
# 14:	learn: 0.5424444	total: 67.8ms	remaining: 384ms
# 15:	learn: 0.5360288	total: 68.2ms	remaining: 358ms
# 16:	learn: 0.5294343	total: 68.5ms	remaining: 334ms
# 17:	learn: 0.5233169	total: 68.9ms	remaining: 314ms
# 18:	learn: 0.5179194	total: 69.2ms	remaining: 295ms
# 19:	learn: 0.5127019	total: 69.5ms	remaining: 278ms
# 20:	learn: 0.5075268	total: 69.8ms	remaining: 263ms
# 21:	learn: 0.5043694	total: 69.9ms	remaining: 248ms
# 22:	learn: 0.4995868	total: 70.3ms	remaining: 235ms
# 23:	learn: 0.4949724	total: 70.5ms	remaining: 223ms
# 24:	learn: 0.4903018	total: 70.9ms	remaining: 213ms
# 25:	learn: 0.4860399	total: 71.1ms	remaining: 202ms
# 26:	learn: 0.4817369	total: 71.4ms	remaining: 193ms
# 27:	learn: 0.4786801	total: 71.7ms	remaining: 184ms
# 28:	learn: 0.4743946	total: 72.3ms	remaining: 177ms
# 29:	learn: 0.4722766	total: 72.4ms	remaining: 169ms
# 30:	learn: 0.4681224	total: 72.7ms	remaining: 162ms
# 31:	learn: 0.4645341	total: 73.1ms	remaining: 155ms
# 32:	learn: 0.4607849	total: 73.5ms	remaining: 149ms
# 33:	learn: 0.4572104	total: 73.9ms	remaining: 143ms
# 34:	learn: 0.4540133	total: 74.1ms	remaining: 138ms
# 35:	learn: 0.4512587	total: 74.5ms	remaining: 132ms
# 36:	learn: 0.4480454	total: 75.7ms	remaining: 129ms
# 37:	learn: 0.4453615	total: 76.3ms	remaining: 125ms
# 38:	learn: 0.4418781	total: 76.6ms	remaining: 120ms
# 39:	learn: 0.4390194	total: 77ms	remaining: 115ms
# 40:	learn: 0.4378940	total: 77.3ms	remaining: 111ms
# 41:	learn: 0.4353155	total: 77.9ms	remaining: 108ms
# 86:	learn: 0.3744145	total: 102ms	remaining: 15.2ms
# 87:	learn: 0.3736066	total: 102ms	remaining: 14ms
# 88:	learn: 0.3727876	total: 103ms	remaining: 12.7ms
# 89:	learn: 0.3717299	total: 103ms	remaining: 11.5ms
# 90:	learn: 0.3714339	total: 104ms	remaining: 10.3ms
# 91:	learn: 0.3703628	total: 104ms	remaining: 9.05ms
# 92:	learn: 0.3693119	total: 105ms	remaining: 7.88ms
# 93:	learn: 0.3678869	total: 106ms	remaining: 6.74ms
# 94:	learn: 0.3672479	total: 107ms	remaining: 5.64ms
# 95:	learn: 0.3662390	total: 108ms	remaining: 4.5ms
# 96:	learn: 0.3654505	total: 109ms	remaining: 3.36ms
# 97:	learn: 0.3645794	total: 109ms	remaining: 2.23ms
# 98:	learn: 0.3637938	total: 110ms	remaining: 1.11ms
# 99:	learn: 0.3622086	total: 110ms	remaining: 0us
# <style type="text/css">
# #T_93f1c_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 82.1%, transparent 82.1%);
# }
# #T_93f1c_row0_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 78.4%, transparent 78.4%);
# }
# #T_93f1c_row1_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 81.7%, transparent 81.7%);
# }
# #T_93f1c_row1_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 79.2%, transparent 79.2%);
# }
# #T_93f1c_row2_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 81.1%, transparent 81.1%);
# }
# #T_93f1c_row2_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 77.9%, transparent 77.9%);
# }
# #T_93f1c_row3_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 80.8%, transparent 80.8%);
# }
# #T_93f1c_row3_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 78.1%, transparent 78.1%);
# }
# #T_93f1c_row4_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 80.6%, transparent 80.6%);
# }
# #T_93f1c_row4_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 78.0%, transparent 78.0%);
# }
# #T_93f1c_row5_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 79.6%, transparent 79.6%);
# }
# #T_93f1c_row5_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 77.4%, transparent 77.4%);
# }
# #T_93f1c_row6_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 78.8%, transparent 78.8%);
# }
# #T_93f1c_row6_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 76.6%, transparent 76.6%);
# }
# #T_93f1c_row7_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 78.2%, transparent 78.2%);
# }
# #T_93f1c_row7_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 76.8%, transparent 76.8%);
# }
# #T_93f1c_row8_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 77.7%, transparent 77.7%);
# }
# #T_93f1c_row8_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 75.1%, transparent 75.1%);
# }
# </style>
# <table id="T_93f1c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >Bal Acc.</th>
#       <th class="col_heading level0 col3" >Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93f1c_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_93f1c_row0_col0" class="data row0 col0" >CatBoost</td>
#       <td id="T_93f1c_row0_col1" class="data row0 col1" >82.051282</td>
#       <td id="T_93f1c_row0_col2" class="data row0 col2" >78.385417</td>
#       <td id="T_93f1c_row0_col3" class="data row0 col3" >0.173446</td>
#     </tr>
#     <tr>
#       <th id="T_93f1c_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_93f1c_row1_col0" class="data row1 col0" >Skl HistGBM</td>
#       <td id="T_93f1c_row1_col1" class="data row1 col1" >81.730769</td>
#       <td id="T_93f1c_row1_col2" class="data row1 col2" >79.218750</td>
#       <td id="T_93f1c_row1_col3" class="data row1 col3" >1.475877</td>
#     </tr>
#     <tr>
#       <th id="T_93f1c_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_93f1c_row2_col0" class="data row2 col0" >Skl GBM</td>
#       <td id="T_93f1c_row2_col1" class="data row2 col1" >81.089744</td>
#       <td id="T_93f1c_row2_col2" class="data row2 col2" >77.916667</td>
#       <td id="T_93f1c_row2_col3" class="data row2 col3" >0.040242</td>
#     </tr>
#     <tr>
#       <th id="T_93f1c_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_93f1c_row3_col0" class="data row3 col0" >Random Forest</td>
#       <td id="T_93f1c_row3_col1" class="data row3 col1" >80.769231</td>
#       <td id="T_93f1c_row3_col2" class="data row3 col2" >78.125000</td>
#       <td id="T_93f1c_row3_col3" class="data row3 col3" >0.075697</td>
#     </tr>
#     <tr>
#       <th id="T_93f1c_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_93f1c_row4_col0" class="data row4 col0" >LightGBM</td>
#       <td id="T_93f1c_row4_col1" class="data row4 col1" >80.608974</td>
#       <td id="T_93f1c_row4_col2" class="data row4 col2" >77.994792</td>
#       <td id="T_93f1c_row4_col3" class="data row4 col3" >0.284893</td>
#     </tr>
#     <tr>
#       <th id="T_93f1c_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_93f1c_row5_col0" class="data row5 col0" >XGBoost</td>
#       <td id="T_93f1c_row5_col1" class="data row5 col1" >79.647436</td>
#       <td id="T_93f1c_row5_col2" class="data row5 col2" >77.447917</td>
#       <td id="T_93f1c_row5_col3" class="data row5 col3" >0.260892</td>
#     </tr>
#     <tr>
#       <th id="T_93f1c_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_93f1c_row6_col0" class="data row6 col0" >Extra Trees</td>
#       <td id="T_93f1c_row6_col1" class="data row6 col1" >78.846154</td>
#       <td id="T_93f1c_row6_col2" class="data row6 col2" >76.640625</td>
#       <td id="T_93f1c_row6_col3" class="data row6 col3" >0.061160</td>
#     </tr>
#     <tr>
#       <th id="T_93f1c_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_93f1c_row7_col0" class="data row7 col0" >Decision Tree</td>
#       <td id="T_93f1c_row7_col1" class="data row7 col1" >78.205128</td>
#       <td id="T_93f1c_row7_col2" class="data row7 col2" >76.822917</td>
#       <td id="T_93f1c_row7_col3" class="data row7 col3" >0.012327</td>
#     </tr>
#     <tr>
#       <th id="T_93f1c_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_93f1c_row8_col0" class="data row8 col0" >AdaBoost</td>
#       <td id="T_93f1c_row8_col1" class="data row8 col1" >77.724359</td>
#       <td id="T_93f1c_row8_col2" class="data row8 col2" >75.104167</td>
#       <td id="T_93f1c_row8_col3" class="data row8 col3" >0.067900</td>
#     </tr>
#   </tbody>
# </table>

# %%
assert results_ord["Accuracy"].min() > 75
assert results_ord["Bal Acc."].min() > 75
assert len(results_ord) == 9

# %% [markdown]
# # Exercise 6 (3pts):
# Define a 10 Fold cross validation strategy with:
# - With stratification
# - shuffle=True
# - random_state=0
#
# And train all the models in a for loop.
#
# Tip you can use **[cross_val_predict](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_val_predict.html)** for both training and predict with

# %%
"""
skf = model_selection.StratifiedKFold(
    # CODE HERE
)
"""
skf = model_selection.StratifiedKFold(n_splits=10, shuffle=True, random_state=0)



results = pd.DataFrame({'Model': [], 'Accuracy': [], 'Bal Acc.': [], 'Time': []})

"""
for model_name, model in tree_classifiers.items():
    start_time = time.time()
        
    # TRAIN AND GET PREDICTIONS USING cross_val_predict() and x,y
    pred = # CODE HERE

    total_time = time.time() - start_time

    results = results.append({"Model":    model_name,
                              "Accuracy": metrics.accuracy_score(y_val, pred)*100,
                              "Bal Acc.": metrics.balanced_accuracy_score(y_val, pred)*100,
                              "Time":     total_time},
                              ignore_index=True)
                              
                              
"""
for model_name, model in tree_classifiers.items():

    start_time = time.time()
    pred = model_selection.cross_val_predict(model, x, y, cv=skf)
    total_time = time.time() - start_time
            
    results = results.append({"Model":    model_name,
                              "Accuracy": metrics.accuracy_score(y, pred)*100,
                              "Bal Acc.": metrics.balanced_accuracy_score(y, pred)*100,
                              "Time":     total_time},
                              ignore_index=True)



results_ord = results.sort_values(by=['Accuracy'], ascending=False, ignore_index=True)
results_ord.index += 1 
results_ord.style.bar(subset=['Accuracy', 'Bal Acc.'], vmin=0, vmax=100, color='#5fba7d')
# Out:
# /Users/talvinderjohal/opt/anaconda3/envs/Tally/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:15:13] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /Users/talvinderjohal/opt/anaconda3/envs/Tally/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:15:14] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /Users/talvinderjohal/opt/anaconda3/envs/Tally/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:15:14] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /Users/talvinderjohal/opt/anaconda3/envs/Tally/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:15:14] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /Users/talvinderjohal/opt/anaconda3/envs/Tally/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:15:15] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /Users/talvinderjohal/opt/anaconda3/envs/Tally/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:15:15] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /Users/talvinderjohal/opt/anaconda3/envs/Tally/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:15:15] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /Users/talvinderjohal/opt/anaconda3/envs/Tally/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:15:16] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /Users/talvinderjohal/opt/anaconda3/envs/Tally/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:15:16] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /Users/talvinderjohal/opt/anaconda3/envs/Tally/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:15:16] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Learning rate set to 0.077408
# 0:	learn: 0.6700511	total: 249us	remaining: 24.7ms
# 1:	learn: 0.6455330	total: 1.03ms	remaining: 50.4ms
# 2:	learn: 0.6280579	total: 1.42ms	remaining: 45.9ms
# 3:	learn: 0.6057286	total: 2.42ms	remaining: 58.1ms
# 4:	learn: 0.5893753	total: 2.94ms	remaining: 55.9ms
# 5:	learn: 0.5711346	total: 3.34ms	remaining: 52.3ms
# 6:	learn: 0.5559002	total: 3.84ms	remaining: 51ms
# 7:	learn: 0.5416820	total: 4.49ms	remaining: 51.6ms
# 8:	learn: 0.5288831	total: 4.94ms	remaining: 50ms
# 9:	learn: 0.5181395	total: 5.37ms	remaining: 48.4ms
# 10:	learn: 0.5084239	total: 5.98ms	remaining: 48.4ms
# 11:	learn: 0.4978915	total: 6.41ms	remaining: 47ms
# 12:	learn: 0.4889679	total: 6.85ms	remaining: 45.8ms
# 13:	learn: 0.4839974	total: 7.26ms	remaining: 44.6ms
# 14:	learn: 0.4763755	total: 7.73ms	remaining: 43.8ms
# 15:	learn: 0.4693834	total: 8.15ms	remaining: 42.8ms
# 16:	learn: 0.4625048	total: 8.6ms	remaining: 42ms
# 17:	learn: 0.4575405	total: 9.04ms	remaining: 41.2ms
# 18:	learn: 0.4530417	total: 9.46ms	remaining: 40.3ms
# 19:	learn: 0.4487703	total: 9.91ms	remaining: 39.6ms
# 20:	learn: 0.4438580	total: 10.3ms	remaining: 38.9ms
# 21:	learn: 0.4397368	total: 10.8ms	remaining: 38.2ms
# 22:	learn: 0.4360042	total: 11.2ms	remaining: 37.5ms
# 23:	learn: 0.4323947	total: 11.6ms	remaining: 36.9ms
# 24:	learn: 0.4285093	total: 12.2ms	remaining: 36.5ms
# 25:	learn: 0.4253184	total: 12.6ms	remaining: 35.9ms
# 26:	learn: 0.4227920	total: 13.2ms	remaining: 35.7ms
# 27:	learn: 0.4199877	total: 13.8ms	remaining: 35.4ms
# 61:	learn: 0.3726326	total: 34.5ms	remaining: 21.1ms
# 62:	learn: 0.3714119	total: 35ms	remaining: 20.6ms
# 63:	learn: 0.3707617	total: 35.6ms	remaining: 20ms
# 64:	learn: 0.3703183	total: 36.1ms	remaining: 19.4ms
# 65:	learn: 0.3701171	total: 36.6ms	remaining: 18.9ms
# 66:	learn: 0.3696003	total: 37.2ms	remaining: 18.3ms
# 67:	learn: 0.3694314	total: 37.5ms	remaining: 17.6ms
# 68:	learn: 0.3686832	total: 38.1ms	remaining: 17.1ms
# 69:	learn: 0.3681083	total: 38.8ms	remaining: 16.6ms
# 70:	learn: 0.3668584	total: 39.4ms	remaining: 16.1ms
# 71:	learn: 0.3661915	total: 39.9ms	remaining: 15.5ms
# 72:	learn: 0.3655572	total: 40.4ms	remaining: 15ms
# 73:	learn: 0.3649456	total: 40.9ms	remaining: 14.4ms
# 74:	learn: 0.3641487	total: 41.4ms	remaining: 13.8ms
# 75:	learn: 0.3632019	total: 41.9ms	remaining: 13.2ms
# 76:	learn: 0.3629077	total: 42.7ms	remaining: 12.7ms
# 77:	learn: 0.3622391	total: 43.3ms	remaining: 12.2ms
# 78:	learn: 0.3620525	total: 43.7ms	remaining: 11.6ms
# 79:	learn: 0.3616766	total: 44.3ms	remaining: 11.1ms
# 80:	learn: 0.3614571	total: 44.9ms	remaining: 10.5ms
# 81:	learn: 0.3601979	total: 45.4ms	remaining: 9.97ms
# 82:	learn: 0.3593976	total: 46ms	remaining: 9.42ms
# 83:	learn: 0.3588815	total: 52.8ms	remaining: 10.1ms
# 84:	learn: 0.3582492	total: 53.8ms	remaining: 9.49ms
# 85:	learn: 0.3578110	total: 54.3ms	remaining: 8.83ms
# 86:	learn: 0.3573592	total: 54.8ms	remaining: 8.19ms
# 87:	learn: 0.3571606	total: 55.8ms	remaining: 7.61ms
# 88:	learn: 0.3570836	total: 56.4ms	remaining: 6.97ms
# 89:	learn: 0.3566104	total: 57.2ms	remaining: 6.35ms
# 90:	learn: 0.3563310	total: 57.8ms	remaining: 5.72ms
# 91:	learn: 0.3557371	total: 58.5ms	remaining: 5.08ms
# 92:	learn: 0.3555090	total: 59.1ms	remaining: 4.45ms
# 93:	learn: 0.3547144	total: 59.6ms	remaining: 3.8ms
# 94:	learn: 0.3546173	total: 60.2ms	remaining: 3.17ms
# 95:	learn: 0.3540275	total: 60.6ms	remaining: 2.53ms
# 96:	learn: 0.3534640	total: 61.1ms	remaining: 1.89ms
# 97:	learn: 0.3531991	total: 61.7ms	remaining: 1.26ms
# 98:	learn: 0.3527897	total: 62.2ms	remaining: 628us
# 99:	learn: 0.3523493	total: 64.4ms	remaining: 0us
# <style type="text/css">
# #T_b9782_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 83.3%, transparent 83.3%);
# }
# #T_b9782_row0_col2, #T_b9782_row7_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 81.0%, transparent 81.0%);
# }
# #T_b9782_row1_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 82.7%, transparent 82.7%);
# }
# #T_b9782_row1_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 80.2%, transparent 80.2%);
# }
# #T_b9782_row2_col1, #T_b9782_row3_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 82.5%, transparent 82.5%);
# }
# #T_b9782_row2_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 80.8%, transparent 80.8%);
# }
# #T_b9782_row3_col2, #T_b9782_row4_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 80.9%, transparent 80.9%);
# }
# #T_b9782_row4_col1, #T_b9782_row5_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 81.9%, transparent 81.9%);
# }
# #T_b9782_row5_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 80.4%, transparent 80.4%);
# }
# #T_b9782_row6_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 81.4%, transparent 81.4%);
# }
# #T_b9782_row6_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 79.9%, transparent 79.9%);
# }
# #T_b9782_row7_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 79.6%, transparent 79.6%);
# }
# #T_b9782_row8_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 78.9%, transparent 78.9%);
# }
# #T_b9782_row8_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 77.6%, transparent 77.6%);
# }
# </style>
# <table id="T_b9782_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >Bal Acc.</th>
#       <th class="col_heading level0 col3" >Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9782_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_b9782_row0_col0" class="data row0 col0" >Skl GBM</td>
#       <td id="T_b9782_row0_col1" class="data row0 col1" >83.277217</td>
#       <td id="T_b9782_row0_col2" class="data row0 col2" >81.027706</td>
#       <td id="T_b9782_row0_col3" class="data row0 col3" >0.640030</td>
#     </tr>
#     <tr>
#       <th id="T_b9782_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_b9782_row1_col0" class="data row1 col0" >CatBoost</td>
#       <td id="T_b9782_row1_col1" class="data row1 col1" >82.716049</td>
#       <td id="T_b9782_row1_col2" class="data row1 col2" >80.241588</td>
#       <td id="T_b9782_row1_col3" class="data row1 col3" >0.930662</td>
#     </tr>
#     <tr>
#       <th id="T_b9782_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_b9782_row2_col0" class="data row2 col0" >Skl HistGBM</td>
#       <td id="T_b9782_row2_col1" class="data row2 col1" >82.491582</td>
#       <td id="T_b9782_row2_col2" class="data row2 col2" >80.831176</td>
#       <td id="T_b9782_row2_col3" class="data row2 col3" >37.452023</td>
#     </tr>
#     <tr>
#       <th id="T_b9782_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_b9782_row3_col0" class="data row3 col0" >LightGBM</td>
#       <td id="T_b9782_row3_col1" class="data row3 col1" >82.491582</td>
#       <td id="T_b9782_row3_col2" class="data row3 col2" >80.886300</td>
#       <td id="T_b9782_row3_col3" class="data row3 col3" >10.093571</td>
#     </tr>
#     <tr>
#       <th id="T_b9782_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_b9782_row4_col0" class="data row4 col0" >AdaBoost</td>
#       <td id="T_b9782_row4_col1" class="data row4 col1" >81.930415</td>
#       <td id="T_b9782_row4_col2" class="data row4 col2" >80.927044</td>
#       <td id="T_b9782_row4_col3" class="data row4 col3" >0.885057</td>
#     </tr>
#     <tr>
#       <th id="T_b9782_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_b9782_row5_col0" class="data row5 col0" >XGBoost</td>
#       <td id="T_b9782_row5_col1" class="data row5 col1" >81.930415</td>
#       <td id="T_b9782_row5_col2" class="data row5 col2" >80.430927</td>
#       <td id="T_b9782_row5_col3" class="data row5 col3" >3.423682</td>
#     </tr>
#     <tr>
#       <th id="T_b9782_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_b9782_row6_col0" class="data row6 col0" >Random Forest</td>
#       <td id="T_b9782_row6_col1" class="data row6 col1" >81.369248</td>
#       <td id="T_b9782_row6_col2" class="data row6 col2" >79.920429</td>
#       <td id="T_b9782_row6_col3" class="data row6 col3" >1.038946</td>
#     </tr>
#     <tr>
#       <th id="T_b9782_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_b9782_row7_col0" class="data row7 col0" >Extra Trees</td>
#       <td id="T_b9782_row7_col1" class="data row7 col1" >81.032548</td>
#       <td id="T_b9782_row7_col2" class="data row7 col2" >79.592081</td>
#       <td id="T_b9782_row7_col3" class="data row7 col3" >0.874821</td>
#     </tr>
#     <tr>
#       <th id="T_b9782_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_b9782_row8_col0" class="data row8 col0" >Decision Tree</td>
#       <td id="T_b9782_row8_col1" class="data row8 col1" >78.900112</td>
#       <td id="T_b9782_row8_col2" class="data row8 col2" >77.641166</td>
#       <td id="T_b9782_row8_col3" class="data row8 col3" >0.097799</td>
#     </tr>
#   </tbody>
# </table>

# %%
assert results_ord["Accuracy"].min() > 75
assert results_ord["Bal Acc."].min() > 75
assert len(results_ord) == 9

# %% [markdown]
# # Exercise 7.1
# Train with all data the best model

# %%
# best_model = tree_classifiers["SELECT MY BEST MODEL HERE"]

# Fit best model with all data

best_model = tree_classifiers[results_ord.iloc[0].Model]
best_model.fit(x,y)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer())]),
#                                                   ['Pclass', 'SibSp', 'Parch',
#                                                    'Fare', 'Age']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='missing',
#                                                                                  strategy='constant')),
#                                                                   ('ordinal',
#                                                                    OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                   unknown_value=-1))]),
#                                                   ['Sex', 'Embarked',
#                                                    'Title'])])),
#                 ('gradientboostingclassifier', GradientBoostingClassifier())])

# %% [markdown]
# # Exercise 7.2 (2pts)
# With your best model, generate the predicitions for test data (x_test)

# %%
# test_pred = # Get the predictions for x_test
test_pred = best_model.predict(x_test)

# %%
assert len(test_pred) == 418
assert np.unique(test_pred).tolist() == [0,1]
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /var/folders/9p/tr5nxpls61zfnl9tjr25j0_40000gn/T/ipykernel_33529/973147442.py in <module>
# ----> 1 assert len(test_pred) == 418
#       2 assert np.unique(test_pred).tolist() == [0,1]
#
# AssertionError:

# %% [markdown]
# # Exercise 7.3
#
# Submit to kaggle.
#
# - You can use the kaggle command line app. Check https://github.com/Kaggle/kaggle-api

# %%
"""sub = pd.DataFrame(test_pred, index=x_test.index, columns=["Survived"])
sub.head()"""

sub = pd.DataFrame(test_pred, index=x_test.index, columns=["Survived"])
sub.head()
# Out:
#              Survived
# PassengerId
# 207                 0
# 438                 1
# 313                 1
# 868                 0
# 683                 0

# %%
'''sub.to_csv("sub.csv")'''
# Out:
# 'sub.to_csv("sub.csv")'

# %%
# !kaggle competitions submit -c titanic -f sub.csv -m "My submission message"
# Out:
# zsh:1: command not found: kaggle
