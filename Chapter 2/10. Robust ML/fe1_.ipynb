# %% [markdown]
# ## Imports

# %%
# pip install --upgrade scikit-learn

# %%
import time
from IPython.display import clear_output
import numpy    as np
import pandas   as pd
import seaborn  as sb
import matplotlib.pyplot as plt
import sklearn  as skl

from sklearn import pipeline      # Pipeline
from sklearn import preprocessing # OrdinalEncoder, LabelEncoder
from sklearn import impute
from sklearn import compose
from sklearn import model_selection # train_test_split
from sklearn import metrics         # accuracy_score, balanced_accuracy_score, plot_confusion_matrix
from sklearn import set_config

set_config(display='diagram') # Useful for display the pipeline

print("Pandas  ", pd.__version__)
print("Sklearn ", skl.__version__) # Try to use 0.24
# Out:
# Pandas   1.3.4
# Sklearn  1.0.2

# %% [markdown]
# ## Get the dataset
# - **CLOUD = True**: Download dataset from Kaggle. Necesary for cloud enviroments like COLAB. **Specify your [kaggle credentials](https://www.kaggle.com/docs/api)**.
# - **CLOUD = False**: Get the dataset from your local machine. **Specify the data path**.

# %%
DATA_PATH = "/Users/talvinderjohal/Desktop/Talvinder Strive Course/ai_nov21/Chapter 2/10. Robust ML"

# %% [markdown]
# ## Load data

# %%
df      = pd.read_csv(DATA_PATH + "/train.csv", index_col='PassengerId')
df_test = pd.read_csv(DATA_PATH + "/test.csv",  index_col='PassengerId')

print("Train DataFrame:", df.shape)
print("Test DataFrame: ", df_test.shape)
# Out:
# Train DataFrame: (891, 11)
# Test DataFrame:  (418, 10)

# %% [markdown]
# ## Check missings

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# Pclass        0
# Name          0
# Sex           0
# Age          86
# SibSp         0
# Parch         0
# Ticket        0
# Fare          1
# Cabin       327
# Embarked      0
# dtype: int64

# %% [markdown]
# # Exercise 1 (2pts):
# Extract the title (Mr, Mrs, ... ) from the "Name" column.
#
# Tips:
# - split(',')[1] to get the 2nd part, and remove the surnamename
# - split('.')[0] to get the 1str part, and remove the name

# %%
# CODE HERE get_Title_from_Name funtion
# Create this function using lambda (not def)

get_Title_from_Name = lambda name: name.split(',')[1].split('.')[0].strip()
df['Title']      = df['Name'].map(get_Title_from_Name)
df_test['Title'] = df_test['Name'].map(get_Title_from_Name)

# %%
assert df['Title'].values[0] == "Mr"
assert df['Title'].values[1] == "Mrs"
assert df['Title'].values[2] == "Miss"

assert df_test['Title'].values[0] == "Mr"
assert df_test['Title'].values[1] == "Mrs"
assert df_test['Title'].values[414] == "Dona"

# %% [markdown]
# # Exercise 2 (1pts):
# Apply the title_dictionary to get a better information about the title. You have to overwrite the Title variable.

# %%
title_dictionary = {
    "Capt": "Officer",
    "Col": "Officer",
    "Major": "Officer",
    "Jonkheer": "Royalty",
    "Don": "Royalty",
    "Sir" : "Royalty",
    "Dr": "Officer",
    "Rev": "Officer",
    "the Countess":"Royalty",
    "Mme": "Mrs",
    "Mlle": "Miss",
    "Ms": "Mrs",
    "Mr" : "Mr",
    "Mrs" : "Mrs",
    "Miss" : "Miss",
    "Master" : "Master",
    "Lady" : "Royalty"
}

# %%
# Use map to apply the prevous dict

df["Title"] =  df.Title.map(title_dictionary)
df_test["Title"] = df_test.Title.map(title_dictionary)

# %%
assert df['Title'].values[886] == "Officer"
assert df_test['Title'].values[417] == "Master"

# %% [markdown]
# # Exercise OPTINAL (0pts):
# Try to extract some information from the feature **Ticket**. Search on Internet if that colum has some kind of information.

# %% [markdown]
# # Exercise OPTIONAL (0pts):
# Try to extract some information from the feature **Cabin**. Search on Internet if that colum has some kind of information.

# %% [markdown]
# # Preprocessing
# For X data, notice that...
# - We drop Survived because is the target variable
# - We drop Name because we have extracted the Title: Mr, Mrs, ...
# - We drop Ticket because it has no information -> see df.Ticket.nunique()
# - We drop Cabin because it has a lot of missings (77% are missings)
#
# Then, we identify **numerical** variables and **categorical** variables,

# %%
x = df.drop(columns=["Survived", 'Name', 'Ticket', 'Cabin']) # X DATA (WILL BE TRAIN+VALID DATA)
y = df["Survived"] # 0 = No, 1 = Yes

x_test = df_test.drop(columns=['Name', 'Ticket', 'Cabin']) # # X_TEST DATA (NEW DATA)

# %%
cat_vars  = ['Sex', 'Embarked', 'Title']         # x.select_dtypes(include=[object]).columns.values.tolist()
num_vars  = ['Pclass', 'SibSp', 'Parch', 'Fare', 'Age'] # x.select_dtypes(exclude=[object]).columns.values.tolist()

print("\nNumerical features:\n", num_vars)
print("\nCategorical features:\n", cat_vars)
# Out:
# Numerical features:
#  ['Pclass', 'SibSp', 'Parch', 'Fare', 'Age']
#
# Categorical features:
#  ['Sex', 'Embarked', 'Title']

# %% [markdown]
# # Exercise 3 (2pts):
# Create a **ColumnTransformer for Tree Models**. You need to create 2 pipelines (one for numerical and other for categories). Remember:
# - Categorical pipeline: Some SimpleImputer -> Some Encoder
# - Numerical pipeline: Some SimpleImputer -> NO Encoder

# %%
"""
num_preprocessing = pipeline.Pipeline(steps=[
  # Some SimpleImputer here
])

cat_preporcessing = pipeline.Pipeline(steps=[
  # Some SimpleImputer here
  # Some Encoder here. Remember to handle_unknown
])

tree_prepro = compose.ColumnTransformer(transformers=[
    ('num', num_preprocessing, num_vars),
    ('cat', cat_preporcessing, cat_vars),
], remainder='drop') # Drop other vars not specified in num_vars or cat_vars

tree_prepro
""";

### BEGIN SOLUTION
num_4_treeModels = pipeline.Pipeline(steps=[('imputer', impute.SimpleImputer(strategy='mean')),])
cat_4_treeModels = pipeline.Pipeline(steps=[('imputer', impute.SimpleImputer(strategy='constant', fill_value='missing')),('ordinal', preprocessing.OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value = -1))])
tree_prepro = compose.ColumnTransformer(transformers=[('num', num_4_treeModels, num_vars),('cat', cat_4_treeModels, cat_vars),], remainder='drop')

tree_prepro
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('imputer', SimpleImputer())]),
#                                  ['Pclass', 'SibSp', 'Parch', 'Fare', 'Age']),
#                                 ('cat',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(fill_value='missing',
#                                                                 strategy='constant')),
#                                                  ('ordinal',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1))]),
#                                  ['Sex', 'Embarked', 'Title'])])

# %%
assert type(tree_prepro)      is compose._column_transformer.ColumnTransformer
assert type(num_4_treeModels) is pipeline.Pipeline
assert type(cat_4_treeModels) is pipeline.Pipeline
assert len(num_4_treeModels) == 1
assert len(cat_4_treeModels) == 2

# %% [markdown]
# # Exercise 4 (1pts):
# 1. Complete the diccionary with some Tree Models.
# 2. Then we put each model in a Pipeline where:
#    - first is the prepocessing with the column Transformer
#    - Then is the Tree model
# 3. Display the fullpipeline of the LGBMClassifier

# %%
from sklearn.tree          import DecisionTreeClassifier
from sklearn.ensemble      import RandomForestClassifier
from sklearn.ensemble      import ExtraTreesClassifier
from sklearn.ensemble      import AdaBoostClassifier
from sklearn.ensemble      import GradientBoostingClassifier
from sklearn.experimental  import enable_hist_gradient_boosting # Necesary for HistGradientBoostingClassifier
from sklearn.ensemble      import HistGradientBoostingClassifier
from xgboost               import XGBClassifier
from lightgbm              import LGBMClassifier
from catboost              import CatBoostClassifier
# Out:
# /Users/talvinderjohal/opt/anaconda3/envs/Tally/lib/python3.9/site-packages/sklearn/experimental/enable_hist_gradient_boosting.py:16: UserWarning: Since version 1.0, it is not needed to import enable_hist_gradient_boosting anymore. HistGradientBoostingClassifier and HistGradientBoostingRegressor are now stable and can be normally imported from sklearn.ensemble.
#   warnings.warn(

# %%
tree_classifiers = {
  "Decision Tree": DecisionTreeClassifier(),
  "Extra Trees":   ExtraTreesClassifier(n_estimators=100),
  "Random Forest": RandomForestClassifier(n_estimators=100),
  "AdaBoost":      AdaBoostClassifier(n_estimators=100),
  "Skl GBM":       GradientBoostingClassifier(n_estimators=100),
  "Skl HistGBM":   HistGradientBoostingClassifier(max_iter=100),
  "XGBoost":       XGBClassifier(n_estimators=100),
  "LightGBM":      LGBMClassifier(n_estimators=100),
  "CatBoost":      CatBoostClassifier(n_estimators=100),
}
tree_classifiers = {name: pipeline.make_pipeline(tree_prepro, model) for name, model in tree_classifiers.items()}
tree_classifiers["LightGBM"]
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer())]),
#                                                   ['Pclass', 'SibSp', 'Parch',
#                                                    'Fare', 'Age']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='missing',
#                                                                                  strategy='constant')),
#                                                                   ('ordinal',
#                                                                    OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                   unknown_value=-1))]),
#                                                   ['Sex', 'Embarked',
#                                                    'Title'])])),
#                 ('lgbmclassifier', LGBMClassifier())])

# %%
for pipe in tree_classifiers.values():
    assert type(pipe) is pipeline.Pipeline

# %% [markdown]
# # Exercise 5 (3pts):
# Define a simple split validation strategy with:
# - 80% for train
# - 20% for validation
# - With stratification
# - random_state=0
#
# And train all the models in a for loop

# %%
"""
x_train, x_val, y_train, y_val = model_selection.train_test_split(
    # CODE HERE
)
"""
results = pd.DataFrame({'Model': [], 'Accuracy': [], 'Bal Acc.': [], 'Time': []})

"""
for model_name, model in tree_classifiers.items():
    start_time = time.time()
    
    # FOR EVERY PIPELINE (PREPRO + MODEL) -> TRAIN WITH TRAIN DATA (x_train)
    
    # GET PREDICTIONS USING x_val
    pred = # CODE HERE

    total_time = time.time() - start_time

    results = results.append({"Model":    model_name,
                              "Accuracy": metrics.accuracy_score(y_val, pred)*100,
                              "Bal Acc.": metrics.balanced_accuracy_score(y_val, pred)*100,
                              "Time":     total_time},
                              ignore_index=True)
                              
                              
"""

### BEGIN SOLUTION
x_train, x_test, y_train, y_test = model_selection.train_test_split(x, y, train_size=0.3, stratify=y, random_state=0)
results = pd.DataFrame({'Model': [], 'Accuracy': [], 'Bal Acc.': [], 'Time': []})
for model_name, model in tree_classifiers.items():

    start_time = time.time()
    model.fit(x_train, y_train)
    total_time = time.time() - start_time
        
    pred = model.predict(x_test)
    
    results = results.append({"Model":    model_name,
                              "Accuracy": metrics.accuracy_score(y_test, pred)*100,
                              "Bal Acc.": metrics.balanced_accuracy_score(y_test, pred)*100,
                              "Time":     total_time},
                              ignore_index=True)




results_ord = results.sort_values(by=['Accuracy'], ascending=False, ignore_index=True)
results_ord.index += 1 
results_ord.style.bar(subset=['Accuracy', 'Bal Acc.'], vmin=0, vmax=100, color='#5fba7d')
# Out:
# /Users/talvinderjohal/opt/anaconda3/envs/Tally/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [19:07:13] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Learning rate set to 0.048423
# 0:	learn: 0.6795697	total: 60.8ms	remaining: 6.02s
# 1:	learn: 0.6666736	total: 61.4ms	remaining: 3.01s
# 2:	learn: 0.6550832	total: 61.6ms	remaining: 1.99s
# 3:	learn: 0.6435277	total: 62.2ms	remaining: 1.49s
# 4:	learn: 0.6344353	total: 62.6ms	remaining: 1.19s
# 5:	learn: 0.6229371	total: 63ms	remaining: 987ms
# 6:	learn: 0.6108504	total: 63.5ms	remaining: 844ms
# 7:	learn: 0.6010858	total: 64ms	remaining: 736ms
# 8:	learn: 0.5911963	total: 64.3ms	remaining: 651ms
# 9:	learn: 0.5810550	total: 64.7ms	remaining: 582ms
# 10:	learn: 0.5717799	total: 65.1ms	remaining: 527ms
# 11:	learn: 0.5646933	total: 65.5ms	remaining: 481ms
# 12:	learn: 0.5561787	total: 66ms	remaining: 442ms
# 13:	learn: 0.5509177	total: 66.3ms	remaining: 407ms
# 14:	learn: 0.5424444	total: 66.8ms	remaining: 379ms
# 15:	learn: 0.5360288	total: 67.4ms	remaining: 354ms
# 16:	learn: 0.5294343	total: 67.8ms	remaining: 331ms
# 17:	learn: 0.5233169	total: 68.3ms	remaining: 311ms
# 18:	learn: 0.5179194	total: 68.8ms	remaining: 293ms
# 19:	learn: 0.5127019	total: 69.4ms	remaining: 278ms
# 20:	learn: 0.5075268	total: 70.1ms	remaining: 264ms
# 21:	learn: 0.5043694	total: 70.3ms	remaining: 249ms
# 22:	learn: 0.4995868	total: 71.3ms	remaining: 239ms
# 23:	learn: 0.4949724	total: 71.7ms	remaining: 227ms
# 24:	learn: 0.4903018	total: 72.5ms	remaining: 218ms
# 70:	learn: 0.3883293	total: 97.3ms	remaining: 39.8ms
# 71:	learn: 0.3877759	total: 97.6ms	remaining: 37.9ms
# 72:	learn: 0.3863748	total: 97.9ms	remaining: 36.2ms
# 73:	learn: 0.3852279	total: 98.2ms	remaining: 34.5ms
# 74:	learn: 0.3843049	total: 98.6ms	remaining: 32.9ms
# 75:	learn: 0.3838978	total: 98.8ms	remaining: 31.2ms
# 76:	learn: 0.3831389	total: 99.1ms	remaining: 29.6ms
# 77:	learn: 0.3820985	total: 99.4ms	remaining: 28ms
# 78:	learn: 0.3809066	total: 99.7ms	remaining: 26.5ms
# 79:	learn: 0.3800227	total: 100ms	remaining: 25ms
# 80:	learn: 0.3792102	total: 100ms	remaining: 23.5ms
# 81:	learn: 0.3785278	total: 101ms	remaining: 22.1ms
# 82:	learn: 0.3775650	total: 101ms	remaining: 20.7ms
# 83:	learn: 0.3768729	total: 101ms	remaining: 19.3ms
# 84:	learn: 0.3761539	total: 102ms	remaining: 18ms
# 85:	learn: 0.3753983	total: 102ms	remaining: 16.7ms
# 86:	learn: 0.3744145	total: 103ms	remaining: 15.4ms
# 87:	learn: 0.3736066	total: 104ms	remaining: 14.1ms
# 88:	learn: 0.3727876	total: 104ms	remaining: 12.9ms
# 89:	learn: 0.3717299	total: 105ms	remaining: 11.6ms
# 90:	learn: 0.3714339	total: 105ms	remaining: 10.4ms
# 91:	learn: 0.3703628	total: 106ms	remaining: 9.19ms
# 92:	learn: 0.3693119	total: 106ms	remaining: 7.98ms
# 93:	learn: 0.3678869	total: 107ms	remaining: 6.81ms
# 94:	learn: 0.3672479	total: 107ms	remaining: 5.63ms
# 95:	learn: 0.3662390	total: 108ms	remaining: 4.49ms
# 96:	learn: 0.3654505	total: 108ms	remaining: 3.35ms
# 97:	learn: 0.3645794	total: 109ms	remaining: 2.22ms
# 98:	learn: 0.3637938	total: 109ms	remaining: 1.1ms
# 99:	learn: 0.3622086	total: 110ms	remaining: 0us
# <style type="text/css">
# #T_4ca32_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 82.1%, transparent 82.1%);
# }
# #T_4ca32_row0_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 78.4%, transparent 78.4%);
# }
# #T_4ca32_row1_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 81.7%, transparent 81.7%);
# }
# #T_4ca32_row1_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 79.2%, transparent 79.2%);
# }
# #T_4ca32_row2_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 81.1%, transparent 81.1%);
# }
# #T_4ca32_row2_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 77.9%, transparent 77.9%);
# }
# #T_4ca32_row3_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 80.6%, transparent 80.6%);
# }
# #T_4ca32_row3_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 78.0%, transparent 78.0%);
# }
# #T_4ca32_row4_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 79.8%, transparent 79.8%);
# }
# #T_4ca32_row4_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 77.0%, transparent 77.0%);
# }
# #T_4ca32_row5_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 79.6%, transparent 79.6%);
# }
# #T_4ca32_row5_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 77.4%, transparent 77.4%);
# }
# #T_4ca32_row6_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 79.5%, transparent 79.5%);
# }
# #T_4ca32_row6_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 77.1%, transparent 77.1%);
# }
# #T_4ca32_row7_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 77.7%, transparent 77.7%);
# }
# #T_4ca32_row7_col2, #T_4ca32_row8_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 75.1%, transparent 75.1%);
# }
# #T_4ca32_row8_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 76.6%, transparent 76.6%);
# }
# </style>
# <table id="T_4ca32_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >Bal Acc.</th>
#       <th class="col_heading level0 col3" >Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ca32_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_4ca32_row0_col0" class="data row0 col0" >CatBoost</td>
#       <td id="T_4ca32_row0_col1" class="data row0 col1" >82.051282</td>
#       <td id="T_4ca32_row0_col2" class="data row0 col2" >78.385417</td>
#       <td id="T_4ca32_row0_col3" class="data row0 col3" >0.168292</td>
#     </tr>
#     <tr>
#       <th id="T_4ca32_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_4ca32_row1_col0" class="data row1 col0" >Skl HistGBM</td>
#       <td id="T_4ca32_row1_col1" class="data row1 col1" >81.730769</td>
#       <td id="T_4ca32_row1_col2" class="data row1 col2" >79.218750</td>
#       <td id="T_4ca32_row1_col3" class="data row1 col3" >1.032538</td>
#     </tr>
#     <tr>
#       <th id="T_4ca32_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_4ca32_row2_col0" class="data row2 col0" >Skl GBM</td>
#       <td id="T_4ca32_row2_col1" class="data row2 col1" >81.089744</td>
#       <td id="T_4ca32_row2_col2" class="data row2 col2" >77.916667</td>
#       <td id="T_4ca32_row2_col3" class="data row2 col3" >0.038329</td>
#     </tr>
#     <tr>
#       <th id="T_4ca32_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_4ca32_row3_col0" class="data row3 col0" >LightGBM</td>
#       <td id="T_4ca32_row3_col1" class="data row3 col1" >80.608974</td>
#       <td id="T_4ca32_row3_col2" class="data row3 col2" >77.994792</td>
#       <td id="T_4ca32_row3_col3" class="data row3 col3" >0.265181</td>
#     </tr>
#     <tr>
#       <th id="T_4ca32_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_4ca32_row4_col0" class="data row4 col0" >Random Forest</td>
#       <td id="T_4ca32_row4_col1" class="data row4 col1" >79.807692</td>
#       <td id="T_4ca32_row4_col2" class="data row4 col2" >76.953125</td>
#       <td id="T_4ca32_row4_col3" class="data row4 col3" >0.073261</td>
#     </tr>
#     <tr>
#       <th id="T_4ca32_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_4ca32_row5_col0" class="data row5 col0" >XGBoost</td>
#       <td id="T_4ca32_row5_col1" class="data row5 col1" >79.647436</td>
#       <td id="T_4ca32_row5_col2" class="data row5 col2" >77.447917</td>
#       <td id="T_4ca32_row5_col3" class="data row5 col3" >0.184815</td>
#     </tr>
#     <tr>
#       <th id="T_4ca32_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_4ca32_row6_col0" class="data row6 col0" >Extra Trees</td>
#       <td id="T_4ca32_row6_col1" class="data row6 col1" >79.487179</td>
#       <td id="T_4ca32_row6_col2" class="data row6 col2" >77.083333</td>
#       <td id="T_4ca32_row6_col3" class="data row6 col3" >0.058527</td>
#     </tr>
#     <tr>
#       <th id="T_4ca32_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_4ca32_row7_col0" class="data row7 col0" >AdaBoost</td>
#       <td id="T_4ca32_row7_col1" class="data row7 col1" >77.724359</td>
#       <td id="T_4ca32_row7_col2" class="data row7 col2" >75.104167</td>
#       <td id="T_4ca32_row7_col3" class="data row7 col3" >0.066823</td>
#     </tr>
#     <tr>
#       <th id="T_4ca32_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_4ca32_row8_col0" class="data row8 col0" >Decision Tree</td>
#       <td id="T_4ca32_row8_col1" class="data row8 col1" >76.602564</td>
#       <td id="T_4ca32_row8_col2" class="data row8 col2" >75.130208</td>
#       <td id="T_4ca32_row8_col3" class="data row8 col3" >0.006191</td>
#     </tr>
#   </tbody>
# </table>

# %%
assert results_ord["Accuracy"].min() > 75
assert results_ord["Bal Acc."].min() > 75
assert len(results_ord) == 9

# %% [markdown]
# # Exercise 6 (3pts):
# Define a 10 Fold cross validation strategy with:
# - With stratification
# - shuffle=True
# - random_state=0
#
# And train all the models in a for loop.
#
# Tip you can use **[cross_val_predict](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_val_predict.html)** for both training and predict with

# %%
"""
skf = model_selection.StratifiedKFold(
    # CODE HERE
)
"""
skf = model_selection.StratifiedKFold(n_splits=10, shuffle=True, random_state=0)



results = pd.DataFrame({'Model': [], 'Accuracy': [], 'Bal Acc.': [], 'Time': []})

"""
for model_name, model in tree_classifiers.items():
    start_time = time.time()
        
    # TRAIN AND GET PREDICTIONS USING cross_val_predict() and x,y
    pred = # CODE HERE

    total_time = time.time() - start_time

    results = results.append({"Model":    model_name,
                              "Accuracy": metrics.accuracy_score(y_val, pred)*100,
                              "Bal Acc.": metrics.balanced_accuracy_score(y_val, pred)*100,
                              "Time":     total_time},
                              ignore_index=True)
                              
                              
"""
for model_name, model in tree_classifiers.items():

    start_time = time.time()
    pred = model_selection.cross_val_predict(model, x, y, cv=skf)
    total_time = time.time() - start_time
            
    results = results.append({"Model":    model_name,
                              "Accuracy": metrics.accuracy_score(y, pred)*100,
                              "Bal Acc.": metrics.balanced_accuracy_score(y, pred)*100,
                              "Time":     total_time},
                              ignore_index=True)



results_ord = results.sort_values(by=['Accuracy'], ascending=False, ignore_index=True)
results_ord.index += 1 
results_ord.style.bar(subset=['Accuracy', 'Bal Acc.'], vmin=0, vmax=100, color='#5fba7d')
# Out:
# /Users/talvinderjohal/opt/anaconda3/envs/Tally/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [19:07:48] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /Users/talvinderjohal/opt/anaconda3/envs/Tally/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [19:07:49] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /Users/talvinderjohal/opt/anaconda3/envs/Tally/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [19:07:49] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /Users/talvinderjohal/opt/anaconda3/envs/Tally/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [19:07:49] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /Users/talvinderjohal/opt/anaconda3/envs/Tally/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [19:07:49] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /Users/talvinderjohal/opt/anaconda3/envs/Tally/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [19:07:49] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /Users/talvinderjohal/opt/anaconda3/envs/Tally/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [19:07:50] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /Users/talvinderjohal/opt/anaconda3/envs/Tally/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [19:07:50] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /Users/talvinderjohal/opt/anaconda3/envs/Tally/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [19:07:50] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /Users/talvinderjohal/opt/anaconda3/envs/Tally/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [19:07:51] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Learning rate set to 0.077408
# 0:	learn: 0.6700511	total: 281us	remaining: 27.9ms
# 1:	learn: 0.6455330	total: 1.52ms	remaining: 74.4ms
# 2:	learn: 0.6280579	total: 1.9ms	remaining: 61.4ms
# 3:	learn: 0.6057286	total: 2.58ms	remaining: 61.9ms
# 4:	learn: 0.5893753	total: 3.06ms	remaining: 58.2ms
# 5:	learn: 0.5711346	total: 3.67ms	remaining: 57.5ms
# 6:	learn: 0.5559002	total: 4.55ms	remaining: 60.4ms
# 7:	learn: 0.5416820	total: 5.16ms	remaining: 59.3ms
# 8:	learn: 0.5288831	total: 5.83ms	remaining: 58.9ms
# 9:	learn: 0.5181395	total: 6.31ms	remaining: 56.8ms
# 10:	learn: 0.5084239	total: 6.93ms	remaining: 56.1ms
# 11:	learn: 0.4978915	total: 7.58ms	remaining: 55.5ms
# 12:	learn: 0.4889679	total: 8.43ms	remaining: 56.4ms
# 13:	learn: 0.4839974	total: 8.91ms	remaining: 54.7ms
# 14:	learn: 0.4763755	total: 9.56ms	remaining: 54.2ms
# 15:	learn: 0.4693834	total: 10.2ms	remaining: 53.7ms
# 16:	learn: 0.4625048	total: 10.9ms	remaining: 53.1ms
# 17:	learn: 0.4575405	total: 12.3ms	remaining: 56.1ms
# 18:	learn: 0.4530417	total: 13.2ms	remaining: 56.3ms
# 19:	learn: 0.4487703	total: 13.7ms	remaining: 54.7ms
# 20:	learn: 0.4438580	total: 14.3ms	remaining: 53.8ms
# 21:	learn: 0.4397368	total: 15.1ms	remaining: 53.4ms
# 22:	learn: 0.4360042	total: 15.6ms	remaining: 52.4ms
# 23:	learn: 0.4323947	total: 16.3ms	remaining: 51.7ms
# 90:	learn: 0.3563310	total: 61.6ms	remaining: 6.09ms
# 91:	learn: 0.3557371	total: 62.2ms	remaining: 5.41ms
# 92:	learn: 0.3555090	total: 62.7ms	remaining: 4.72ms
# 93:	learn: 0.3547144	total: 63.2ms	remaining: 4.03ms
# 94:	learn: 0.3546173	total: 63.6ms	remaining: 3.35ms
# 95:	learn: 0.3540275	total: 64.1ms	remaining: 2.67ms
# 96:	learn: 0.3534640	total: 64.6ms	remaining: 2ms
# 97:	learn: 0.3531991	total: 65.1ms	remaining: 1.33ms
# 98:	learn: 0.3527897	total: 65.7ms	remaining: 663us
# 99:	learn: 0.3523493	total: 66.2ms	remaining: 0us
# <style type="text/css">
# #T_7e85f_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 83.2%, transparent 83.2%);
# }
# #T_7e85f_row0_col2, #T_7e85f_row3_col2, #T_7e85f_row4_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 80.9%, transparent 80.9%);
# }
# #T_7e85f_row1_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 82.7%, transparent 82.7%);
# }
# #T_7e85f_row1_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 80.2%, transparent 80.2%);
# }
# #T_7e85f_row2_col1, #T_7e85f_row3_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 82.5%, transparent 82.5%);
# }
# #T_7e85f_row2_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 80.8%, transparent 80.8%);
# }
# #T_7e85f_row4_col1, #T_7e85f_row5_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 81.9%, transparent 81.9%);
# }
# #T_7e85f_row5_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 80.4%, transparent 80.4%);
# }
# #T_7e85f_row6_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 81.5%, transparent 81.5%);
# }
# #T_7e85f_row6_col2, #T_7e85f_row7_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 80.1%, transparent 80.1%);
# }
# #T_7e85f_row7_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 78.8%, transparent 78.8%);
# }
# #T_7e85f_row8_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 79.2%, transparent 79.2%);
# }
# #T_7e85f_row8_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 78.0%, transparent 78.0%);
# }
# </style>
# <table id="T_7e85f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >Bal Acc.</th>
#       <th class="col_heading level0 col3" >Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e85f_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_7e85f_row0_col0" class="data row0 col0" >Skl GBM</td>
#       <td id="T_7e85f_row0_col1" class="data row0 col1" >83.164983</td>
#       <td id="T_7e85f_row0_col2" class="data row0 col2" >80.881507</td>
#       <td id="T_7e85f_row0_col3" class="data row0 col3" >0.722827</td>
#     </tr>
#     <tr>
#       <th id="T_7e85f_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_7e85f_row1_col0" class="data row1 col0" >CatBoost</td>
#       <td id="T_7e85f_row1_col1" class="data row1 col1" >82.716049</td>
#       <td id="T_7e85f_row1_col2" class="data row1 col2" >80.241588</td>
#       <td id="T_7e85f_row1_col3" class="data row1 col3" >0.953175</td>
#     </tr>
#     <tr>
#       <th id="T_7e85f_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_7e85f_row2_col0" class="data row2 col0" >Skl HistGBM</td>
#       <td id="T_7e85f_row2_col1" class="data row2 col1" >82.491582</td>
#       <td id="T_7e85f_row2_col2" class="data row2 col2" >80.831176</td>
#       <td id="T_7e85f_row2_col3" class="data row2 col3" >30.988424</td>
#     </tr>
#     <tr>
#       <th id="T_7e85f_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_7e85f_row3_col0" class="data row3 col0" >LightGBM</td>
#       <td id="T_7e85f_row3_col1" class="data row3 col1" >82.491582</td>
#       <td id="T_7e85f_row3_col2" class="data row3 col2" >80.886300</td>
#       <td id="T_7e85f_row3_col3" class="data row3 col3" >7.980576</td>
#     </tr>
#     <tr>
#       <th id="T_7e85f_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_7e85f_row4_col0" class="data row4 col0" >AdaBoost</td>
#       <td id="T_7e85f_row4_col1" class="data row4 col1" >81.930415</td>
#       <td id="T_7e85f_row4_col2" class="data row4 col2" >80.927044</td>
#       <td id="T_7e85f_row4_col3" class="data row4 col3" >0.989800</td>
#     </tr>
#     <tr>
#       <th id="T_7e85f_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_7e85f_row5_col0" class="data row5 col0" >XGBoost</td>
#       <td id="T_7e85f_row5_col1" class="data row5 col1" >81.930415</td>
#       <td id="T_7e85f_row5_col2" class="data row5 col2" >80.430927</td>
#       <td id="T_7e85f_row5_col3" class="data row5 col3" >2.772038</td>
#     </tr>
#     <tr>
#       <th id="T_7e85f_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_7e85f_row6_col0" class="data row6 col0" >Random Forest</td>
#       <td id="T_7e85f_row6_col1" class="data row6 col1" >81.481481</td>
#       <td id="T_7e85f_row6_col2" class="data row6 col2" >80.066628</td>
#       <td id="T_7e85f_row6_col3" class="data row6 col3" >1.133021</td>
#     </tr>
#     <tr>
#       <th id="T_7e85f_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_7e85f_row7_col0" class="data row7 col0" >Extra Trees</td>
#       <td id="T_7e85f_row7_col1" class="data row7 col1" >80.134680</td>
#       <td id="T_7e85f_row7_col2" class="data row7 col2" >78.753236</td>
#       <td id="T_7e85f_row7_col3" class="data row7 col3" >0.895384</td>
#     </tr>
#     <tr>
#       <th id="T_7e85f_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_7e85f_row8_col0" class="data row8 col0" >Decision Tree</td>
#       <td id="T_7e85f_row8_col1" class="data row8 col1" >79.236813</td>
#       <td id="T_7e85f_row8_col2" class="data row8 col2" >78.024638</td>
#       <td id="T_7e85f_row8_col3" class="data row8 col3" >0.091631</td>
#     </tr>
#   </tbody>
# </table>

# %%
assert results_ord["Accuracy"].min() > 75
assert results_ord["Bal Acc."].min() > 75
assert len(results_ord) == 9

# %% [markdown]
# # Exercise 7.1
# Train with all data the best model

# %%
# best_model = tree_classifiers["SELECT MY BEST MODEL HERE"]

# Fit best model with all data

best_model = tree_classifiers[results_ord.iloc[0].Model]
best_model.fit(x,y)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer())]),
#                                                   ['Pclass', 'SibSp', 'Parch',
#                                                    'Fare', 'Age']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='missing',
#                                                                                  strategy='constant')),
#                                                                   ('ordinal',
#                                                                    OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                   unknown_value=-1))]),
#                                                   ['Sex', 'Embarked',
#                                                    'Title'])])),
#                 ('gradientboostingclassifier', GradientBoostingClassifier())])

# %% [markdown]
# # Exercise 7.2 (2pts)
# With your best model, generate the predicitions for test data (x_test)

# %%
# test_pred = # Get the predictions for x_test
test_pred = best_model.predict(x_test)

# %%
assert len(test_pred) == 418
assert np.unique(test_pred).tolist() == [0,1]
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /var/folders/9p/tr5nxpls61zfnl9tjr25j0_40000gn/T/ipykernel_1682/973147442.py in <module>
# ----> 1 assert len(test_pred) == 418
#       2 assert np.unique(test_pred).tolist() == [0,1]
#
# AssertionError:

# %% [markdown]
# # Exercise 7.3
#
# Submit to kaggle.
#
# - You can use the kaggle command line app. Check https://github.com/Kaggle/kaggle-api

# %%
"""sub = pd.DataFrame(test_pred, index=x_test.index, columns=["Survived"])
sub.head()"""

sub = pd.DataFrame(test_pred, index=x_test.index, columns=["Survived"])
sub.head()
# Out:
#              Survived
# PassengerId
# 207                 0
# 438                 1
# 313                 1
# 868                 0
# 683                 0

# %%
'''sub.to_csv("sub.csv")'''
# Out:
# 'sub.to_csv("sub.csv")'

# %%
# !kaggle competitions submit -c titanic -f sub.csv -m "My submission message"
# Out:
# zsh:1: command not found: kaggle
